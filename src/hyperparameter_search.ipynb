# %% [markdown]
# # Hyperparameter Search for MLP Pipeline
#
# This notebook performs hyperparameter optimization for the MLP-based PTM prediction pipeline. It can be run for any PTM type that uses the standard schema (acet_k, gly_n, phos_y, sumo_k). It searches over architecture (hidden dimensions, dropout), learning rate, and batch size, then stores the best configuration and results under `docs/ptm_<PTM_TYPE>/`.

# %%
PTM_TYPE = "phos_y"
MAX_CONFIGS = 150

import pandas as pd
import numpy as np
import json
import random
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    average_precision_score, matthews_corrcoef,
)
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import warnings
import itertools
from datetime import datetime
warnings.filterwarnings("ignore")

DATA_DIR = Path("../datasets")
RESULTS_DIR = Path(f"../docs/ptm_{PTM_TYPE}")
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
SEED = 42

# %% [markdown]
# ## Load pipeline functions
#
# We import or redefine the necessary functions from `simple_pipeline.ipynb`.

# %%
# Standard 20 amino acids (one-letter); index 20 = unknown
AA_ALPHABET = "ACDEFGHIKLMNPQRSTVWY"
AA_TO_IDX = {a: i for i, a in enumerate(AA_ALPHABET)}
AA_TO_IDX["X"] = 20
NUM_AAS = 21

NUMERIC_FEATURES = [
    "embedding_dispersion", "center_window_dispersion",
    "embedding_entropy", "center_window_entropy",
    "svd_entropy", "center_svd_entropy",
]

def encode_sequence(seq, window_len, aa_to_idx, num_aas):
    """One-hot encode sequence to fixed length."""
    out = np.zeros((window_len, num_aas), dtype=np.float32)
    for i, aa in enumerate(seq[:window_len]):
        idx = aa_to_idx.get(aa, 20)
        out[i, idx] = 1.0
    return out.flatten()

def build_features(df, window_len):
    seq_vecs = np.array([
        encode_sequence(s, window_len, AA_TO_IDX, NUM_AAS)
        for s in df["original_sequence"]
    ])
    num_feat = df[NUMERIC_FEATURES].values.astype(np.float32)
    return np.hstack([seq_vecs, num_feat])

class WindowDataset(Dataset):
    def __init__(self, X, y):
        # MPS (Metal) only supports float32; ensure no float64 from numpy
        self.X = torch.from_numpy(np.asarray(X, dtype=np.float32))
        self.y = torch.from_numpy(np.asarray(y, dtype=np.float32)).unsqueeze(1)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dims=(512, 256), dropout=0.3):
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_dims:
            layers.extend([nn.Linear(prev, h), nn.ReLU(), nn.Dropout(dropout)])
            prev = h
        self.backbone = nn.Sequential(*layers)
        self.head = nn.Linear(prev, 1)

    def forward(self, x):
        return self.head(self.backbone(x)).squeeze(-1)

def compute_metrics(y_true, y_prob, threshold=0.5):
    y_pred = (y_prob >= threshold).astype(int)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    auprc = average_precision_score(y_true, y_prob)
    mcc = matthews_corrcoef(y_true, y_pred)
    return {"precision": precision, "recall": recall, "f1": f1, "auprc": auprc, "mcc": mcc}

def evaluate(model, loader, device):
    model.eval()
    all_prob, all_y = [], []
    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            logits = model(X)
            prob = torch.sigmoid(logits).cpu().numpy()
            all_prob.append(prob)
            all_y.append(y.cpu().numpy().ravel())
    y_prob = np.concatenate(all_prob)
    y_true = np.concatenate(all_y)
    return y_true, y_prob, compute_metrics(y_true, y_prob)

# %% [markdown]
# ## Load and prepare data
#
# Load data for the selected PTM type and perform protein-wise train/val/test split (same as simple_pipeline.ipynb).

# %%
train_df = pd.read_csv(DATA_DIR / f"{PTM_TYPE}_train.csv")
test_df = pd.read_csv(DATA_DIR / f"{PTM_TYPE}_test.csv")

window_len = len(train_df["original_sequence"].iloc[0])
print(f"Window length: {window_len}")

# Protein-wise split
protein_ids = train_df["UniProt_ID"].unique()
train_proteins, val_proteins = train_test_split(
    protein_ids, test_size=0.2, random_state=SEED
)

train_split = train_df[train_df["UniProt_ID"].isin(train_proteins)].copy()
val_split = train_df[train_df["UniProt_ID"].isin(val_proteins)].copy()

# Build features
X_train = build_features(train_split, window_len)
y_train = train_split["ptm_type"].values
X_val = build_features(val_split, window_len)
y_val = val_split["ptm_type"].values
X_test = build_features(test_df, window_len)
y_test = test_df["ptm_type"].values

print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Window length: 101
# Train: 46628, Val: 12093, Test: 5814

# %% [markdown]
# ## Define hyperparameter search space
#
# We search over:
# - **Hidden dimensions**: Different architectures
# - **Dropout**: Regularization strength
# - **Learning rate**: Optimization speed
# - **Batch size**: Training dynamics

# %%
# Hyperparameter grid
HYPERPARAM_GRID = {
    "hidden_dims": [
        (256, 128),
        (512, 256),
        (512, 256, 128),
        (1024, 512),
        (1024, 512, 256),
    ],
    "dropout": [0.2, 0.3, 0.4, 0.5],
    "learning_rate": [1e-4, 5e-4, 1e-3, 2e-3],
    "batch_size": [128, 256, 512],
}

# Generate all combinations, then limit to MAX_CONFIGS per run
keys = list(HYPERPARAM_GRID.keys())
values = list(HYPERPARAM_GRID.values())
full_configs = [dict(zip(keys, v)) for v in itertools.product(*values)]
random.seed(SEED)
configs = random.sample(full_configs, min(MAX_CONFIGS, len(full_configs)))

print(f"Total configurations to test: {len(configs)} (capped from {len(full_configs)})")
print(f"Sample config: {configs[0]}")
# Out:
# Total configurations to test: 240
# Sample config: {'hidden_dims': (256, 128), 'dropout': 0.2, 'learning_rate': 0.0001, 'batch_size': 128}

# %% [markdown]
# ## Training function
#
# Wrapper function that trains with given hyperparameters and returns results.

# %%
def train_with_config(
    config, X_train, y_train, X_val, y_val, X_test, y_test,
    num_epochs=15, device=None, verbose=False, seed=42
):
    """Train MLP with given hyperparameter configuration."""
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Set seeds
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
    
    # Compute pos_weight
    n_pos = y_train.sum()
    n_neg = len(y_train) - n_pos
    pos_weight = float(n_neg) / max(n_pos, 1)
    
    # Create datasets and loaders
    train_ds = WindowDataset(X_train, y_train)
    val_ds = WindowDataset(X_val, y_val)
    train_loader = DataLoader(
        train_ds, batch_size=config["batch_size"], shuffle=True, num_workers=0
    )
    val_loader = DataLoader(
        val_ds, batch_size=config["batch_size"], shuffle=False, num_workers=0
    )
    
    # Create model
    input_dim = X_train.shape[1]
    model = MLP(
        input_dim,
        hidden_dims=config["hidden_dims"],
        dropout=config["dropout"]
    ).to(device)
    
    criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([pos_weight], dtype=torch.float32, device=device))
    optimizer = torch.optim.Adam(model.parameters(), lr=config["learning_rate"])
    
    # Training loop
    best_val_auprc = 0.0
    best_state = None
    history = {"train_loss": [], "val_auprc": []}
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            optimizer.zero_grad()
            logits = model(X)
            loss = criterion(logits, y.squeeze(1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        train_loss = running_loss / len(train_loader)
        history["train_loss"].append(train_loss)
        
        # Validation
        y_val_true, y_val_prob, val_metrics = evaluate(model, val_loader, device)
        history["val_auprc"].append(val_metrics["auprc"])
        
        if val_metrics["auprc"] > best_val_auprc:
            best_val_auprc = val_metrics["auprc"]
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
    
    # Load best model and evaluate on test set
    model.load_state_dict(best_state)
    test_loader = DataLoader(
        WindowDataset(X_test, y_test),
        batch_size=config["batch_size"],
        shuffle=False,
        num_workers=0
    )
    y_test_true, y_test_prob, test_metrics = evaluate(model, test_loader, device)
    
    return {
        "config": config,
        "best_val_auprc": best_val_auprc,
        "test_metrics": test_metrics,
        "history": history,
        "final_train_loss": history["train_loss"][-1]
    }

# %% [markdown]
# ## Run hyperparameter search
#
# Loop over all configurations and store results. This may take a while depending on the number of configs and epochs.

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.backends.mps.is_available():
            device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")

results = []
num_epochs = 15

for idx, config in enumerate(configs):
    print(f"\n[{idx+1}/{len(configs)}] Testing config:")
    print(f"  hidden_dims={config['hidden_dims']}, dropout={config['dropout']}, "
          f"lr={config['learning_rate']}, batch_size={config['batch_size']}")
    
    try:
        result = train_with_config(
            config, X_train, y_train, X_val, y_val, X_test, y_test,
            num_epochs=num_epochs, device=device, verbose=False, seed=SEED
        )
        
        results.append({
            "config_id": idx,
            "hidden_dims": str(config["hidden_dims"]),
            "dropout": config["dropout"],
            "learning_rate": config["learning_rate"],
            "batch_size": config["batch_size"],
            "best_val_auprc": result["best_val_auprc"],
            "test_precision": result["test_metrics"]["precision"],
            "test_recall": result["test_metrics"]["recall"],
            "test_f1": result["test_metrics"]["f1"],
            "test_auprc": result["test_metrics"]["auprc"],
            "test_mcc": result["test_metrics"]["mcc"],
            "final_train_loss": result["final_train_loss"]
        })
        
        print(f"  Val AUPRC: {result['best_val_auprc']:.4f}, Test AUPRC: {result['test_metrics']['auprc']:.4f}")
        
    except Exception as e:
        print(f"  ERROR: {e}")
        results.append({
            "config_id": idx,
            "hidden_dims": str(config["hidden_dims"]),
            "dropout": config["dropout"],
            "learning_rate": config["learning_rate"],
            "batch_size": config["batch_size"],
            "error": str(e)
        })

print(f"\nCompleted {len(results)} configurations.")
# Out:
# Using device: mps
#
# [1/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4658, Test AUPRC: 0.4515
#
# [2/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4660, Test AUPRC: 0.4575
#
# [3/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4498, Test AUPRC: 0.4482
#
# [4/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4636, Test AUPRC: 0.4439
#
# [5/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4651, Test AUPRC: 0.4357
#
# [6/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4623, Test AUPRC: 0.4481
#
# [7/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.001, batch_size=128
#   Val AUPRC: 0.4607, Test AUPRC: 0.4456
#
# [8/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.001, batch_size=256
#   Val AUPRC: 0.4713, Test AUPRC: 0.4498
#
# [9/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.001, batch_size=512
#   Val AUPRC: 0.4647, Test AUPRC: 0.4305
#
# [10/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.002, batch_size=128
#   Val AUPRC: 0.4571, Test AUPRC: 0.4389
#
# [11/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.002, batch_size=256
#   Val AUPRC: 0.4577, Test AUPRC: 0.4446
#
# [12/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.2, lr=0.002, batch_size=512
#   Val AUPRC: 0.4637, Test AUPRC: 0.4193
#
# [13/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4722, Test AUPRC: 0.4461
#
# [14/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4673, Test AUPRC: 0.4612
#
# [15/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4481, Test AUPRC: 0.4591
#
# [16/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4699, Test AUPRC: 0.4348
#
# [17/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4709, Test AUPRC: 0.4385
#
# [18/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4672, Test AUPRC: 0.4345
#
# [19/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.001, batch_size=128
#   Val AUPRC: 0.4618, Test AUPRC: 0.4299
#
# [20/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.001, batch_size=256
#   Val AUPRC: 0.4677, Test AUPRC: 0.4399
#
# [21/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.001, batch_size=512
#   Val AUPRC: 0.4617, Test AUPRC: 0.4269
#
# [22/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.002, batch_size=128
#   Val AUPRC: 0.4590, Test AUPRC: 0.4173
#
# [23/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.002, batch_size=256
#   Val AUPRC: 0.4758, Test AUPRC: 0.4449
#
# [24/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.3, lr=0.002, batch_size=512
#   Val AUPRC: 0.4550, Test AUPRC: 0.4478
#
# [25/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4705, Test AUPRC: 0.4560
#
# [26/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4612, Test AUPRC: 0.4570
#
# [27/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4431, Test AUPRC: 0.4582
#
# [28/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4726, Test AUPRC: 0.4327
#
# [29/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4743, Test AUPRC: 0.4489
#
# [30/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4703, Test AUPRC: 0.4438
#
# [31/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.001, batch_size=128
#   Val AUPRC: 0.4603, Test AUPRC: 0.4419
#
# [32/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.001, batch_size=256
#   Val AUPRC: 0.4632, Test AUPRC: 0.4296
#
# [33/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.001, batch_size=512
#   Val AUPRC: 0.4692, Test AUPRC: 0.4267
#
# [34/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.002, batch_size=128
#   Val AUPRC: 0.4682, Test AUPRC: 0.4434
#
# [35/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.002, batch_size=256
#   Val AUPRC: 0.4579, Test AUPRC: 0.4053
#
# [36/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.4, lr=0.002, batch_size=512
#   Val AUPRC: 0.4695, Test AUPRC: 0.4540
#
# [37/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4725, Test AUPRC: 0.4535
#
# [38/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4565, Test AUPRC: 0.4564
#
# [39/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4379, Test AUPRC: 0.4606
#
# [40/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4771, Test AUPRC: 0.4410
#
# [41/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4811, Test AUPRC: 0.4496
#
# [42/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4695, Test AUPRC: 0.4501
#
# [43/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.001, batch_size=128
#   Val AUPRC: 0.4739, Test AUPRC: 0.4281
#
# [44/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.001, batch_size=256
#   Val AUPRC: 0.4712, Test AUPRC: 0.4363
#
# [45/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.001, batch_size=512
#   Val AUPRC: 0.4733, Test AUPRC: 0.4430
#
# [46/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.002, batch_size=128
#   Val AUPRC: 0.4735, Test AUPRC: 0.4333
#
# [47/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.002, batch_size=256
#   Val AUPRC: 0.4723, Test AUPRC: 0.4400
#
# [48/240] Testing config:
#   hidden_dims=(256, 128), dropout=0.5, lr=0.002, batch_size=512
#   Val AUPRC: 0.4678, Test AUPRC: 0.4489
#
# [49/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4798, Test AUPRC: 0.4575
#
# [50/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4802, Test AUPRC: 0.4674
#
# [51/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4738, Test AUPRC: 0.4610
#
# [52/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4765, Test AUPRC: 0.4529
#
# [53/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4805, Test AUPRC: 0.4566
#
# [54/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4774, Test AUPRC: 0.4497
#
# [55/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.001, batch_size=128
#   Val AUPRC: 0.4754, Test AUPRC: 0.4543
#
# [56/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.001, batch_size=256
#   Val AUPRC: 0.4757, Test AUPRC: 0.4534
#
# [57/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.001, batch_size=512
#   Val AUPRC: 0.4744, Test AUPRC: 0.4279
#
# [58/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.002, batch_size=128
#   Val AUPRC: 0.4738, Test AUPRC: 0.4434
#
# [59/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.002, batch_size=256
#   Val AUPRC: 0.4677, Test AUPRC: 0.4440
#
# [60/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.2, lr=0.002, batch_size=512
#   Val AUPRC: 0.4780, Test AUPRC: 0.4365
#
# [61/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4766, Test AUPRC: 0.4550
#
# [62/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4798, Test AUPRC: 0.4673
#
# [63/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4715, Test AUPRC: 0.4613
#
# [64/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4791, Test AUPRC: 0.4536
#
# [65/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4809, Test AUPRC: 0.4491
#
# [66/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4808, Test AUPRC: 0.4506
#
# [67/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.001, batch_size=128
#   Val AUPRC: 0.4752, Test AUPRC: 0.4545
#
# [68/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.001, batch_size=256
#   Val AUPRC: 0.4722, Test AUPRC: 0.4484
#
# [69/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.001, batch_size=512
#   Val AUPRC: 0.4775, Test AUPRC: 0.4353
#
# [70/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.002, batch_size=128
#   Val AUPRC: 0.4672, Test AUPRC: 0.4509
#
# [71/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.002, batch_size=256
#   Val AUPRC: 0.4656, Test AUPRC: 0.4017
#
# [72/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.3, lr=0.002, batch_size=512
#   Val AUPRC: 0.4793, Test AUPRC: 0.4430
#
# [73/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4798, Test AUPRC: 0.4644
#
# [74/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4824, Test AUPRC: 0.4559
#
# [75/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4712, Test AUPRC: 0.4627
#
# [76/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4772, Test AUPRC: 0.4466
#
# [77/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4832, Test AUPRC: 0.4542
#
# [78/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4801, Test AUPRC: 0.4615
#
# [79/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.001, batch_size=128
#   Val AUPRC: 0.4717, Test AUPRC: 0.4296
#
# [80/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.001, batch_size=256
#   Val AUPRC: 0.4699, Test AUPRC: 0.4469
#
# [81/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.001, batch_size=512
#   Val AUPRC: 0.4801, Test AUPRC: 0.4527
#
# [82/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.002, batch_size=128
#   Val AUPRC: 0.4715, Test AUPRC: 0.4185
#
# [83/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.002, batch_size=256
#   Val AUPRC: 0.4696, Test AUPRC: 0.4545
#
# [84/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.4, lr=0.002, batch_size=512
#   Val AUPRC: 0.4789, Test AUPRC: 0.4349
#
# [85/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4800, Test AUPRC: 0.4698
#
# [86/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4777, Test AUPRC: 0.4644
#
# [87/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4682, Test AUPRC: 0.4628
#
# [88/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4808, Test AUPRC: 0.4491
#
# [89/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4815, Test AUPRC: 0.4423
#
# [90/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4799, Test AUPRC: 0.4589
#
# [91/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.001, batch_size=128
#   Val AUPRC: 0.4846, Test AUPRC: 0.4378
#
# [92/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.001, batch_size=256
#   Val AUPRC: 0.4848, Test AUPRC: 0.4348
#
# [93/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.001, batch_size=512
#   Val AUPRC: 0.4839, Test AUPRC: 0.4439
#
# [94/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.002, batch_size=128
#   Val AUPRC: 0.4717, Test AUPRC: 0.4357
#
# [95/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.002, batch_size=256
#   Val AUPRC: 0.4826, Test AUPRC: 0.4516
#
# [96/240] Testing config:
#   hidden_dims=(512, 256), dropout=0.5, lr=0.002, batch_size=512
#   Val AUPRC: 0.4754, Test AUPRC: 0.4347
#
# [97/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4613, Test AUPRC: 0.4394
#
# [98/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4635, Test AUPRC: 0.4581
#
# [99/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4699, Test AUPRC: 0.4467
#
# [100/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4638, Test AUPRC: 0.4587
#
# [101/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4606, Test AUPRC: 0.4440
#
# [102/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4727, Test AUPRC: 0.4330
#
# [103/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.001, batch_size=128
#   Val AUPRC: 0.4752, Test AUPRC: 0.4506
#
# [104/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.001, batch_size=256
#   Val AUPRC: 0.4693, Test AUPRC: 0.4559
#
# [105/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.001, batch_size=512
#   Val AUPRC: 0.4635, Test AUPRC: 0.4337
#
# [106/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.002, batch_size=128
#   Val AUPRC: 0.4698, Test AUPRC: 0.4513
#
# [107/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.002, batch_size=256
#   Val AUPRC: 0.4813, Test AUPRC: 0.4540
#
# [108/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.2, lr=0.002, batch_size=512
#   Val AUPRC: 0.4605, Test AUPRC: 0.4529
#
# [109/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4688, Test AUPRC: 0.4300
#
# [110/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4719, Test AUPRC: 0.4518
#
# [111/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4730, Test AUPRC: 0.4499
#
# [112/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4673, Test AUPRC: 0.4352
#
# [113/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4638, Test AUPRC: 0.4425
#
# [114/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4665, Test AUPRC: 0.4281
#
# [115/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.001, batch_size=128
#   Val AUPRC: 0.4754, Test AUPRC: 0.4630
#
# [116/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.001, batch_size=256
#   Val AUPRC: 0.4670, Test AUPRC: 0.4245
#
# [117/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.001, batch_size=512
#   Val AUPRC: 0.4689, Test AUPRC: 0.4361
#
# [118/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.002, batch_size=128
#   Val AUPRC: 0.4674, Test AUPRC: 0.4612
#
# [119/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.002, batch_size=256
#   Val AUPRC: 0.4775, Test AUPRC: 0.4586
#
# [120/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.3, lr=0.002, batch_size=512
#   Val AUPRC: 0.4757, Test AUPRC: 0.4391
#
# [121/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4686, Test AUPRC: 0.4412
#
# [122/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4710, Test AUPRC: 0.4599
#
# [123/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4706, Test AUPRC: 0.4358
#
# [124/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4733, Test AUPRC: 0.4438
#
# [125/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4695, Test AUPRC: 0.4323
#
# [126/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4731, Test AUPRC: 0.4388
#
# [127/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.001, batch_size=128
#   Val AUPRC: 0.4744, Test AUPRC: 0.4345
#
# [128/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.001, batch_size=256
#   Val AUPRC: 0.4696, Test AUPRC: 0.4205
#
# [129/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.001, batch_size=512
#   Val AUPRC: 0.4773, Test AUPRC: 0.4310
#
# [130/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.002, batch_size=128
#   Val AUPRC: 0.4694, Test AUPRC: 0.4336
#
# [131/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.002, batch_size=256
#   Val AUPRC: 0.4677, Test AUPRC: 0.4445
#
# [132/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.4, lr=0.002, batch_size=512
#   Val AUPRC: 0.4658, Test AUPRC: 0.4228
#
# [133/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4746, Test AUPRC: 0.4512
#
# [134/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4717, Test AUPRC: 0.4627
#
# [135/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4639, Test AUPRC: 0.4507
#
# [136/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4783, Test AUPRC: 0.4436
#
# [137/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4802, Test AUPRC: 0.4447
#
# [138/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4775, Test AUPRC: 0.4410
#
# [139/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.001, batch_size=128
#   Val AUPRC: 0.4733, Test AUPRC: 0.4419
#
# [140/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.001, batch_size=256
#   Val AUPRC: 0.4705, Test AUPRC: 0.4364
#
# [141/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.001, batch_size=512
#   Val AUPRC: 0.4745, Test AUPRC: 0.4402
#
# [142/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.002, batch_size=128
#   Val AUPRC: 0.4801, Test AUPRC: 0.4230
#
# [143/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.002, batch_size=256
#   Val AUPRC: 0.4777, Test AUPRC: 0.4419
#
# [144/240] Testing config:
#   hidden_dims=(512, 256, 128), dropout=0.5, lr=0.002, batch_size=512
#   Val AUPRC: 0.4732, Test AUPRC: 0.4396
#
# [145/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4813, Test AUPRC: 0.4670
#
# [146/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4831, Test AUPRC: 0.4682
#
# [147/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4836, Test AUPRC: 0.4708
#
# [148/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4831, Test AUPRC: 0.4684
#
# [149/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4801, Test AUPRC: 0.4441
#
# [150/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4808, Test AUPRC: 0.4599
#
# [151/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.001, batch_size=128
#   Val AUPRC: 0.4902, Test AUPRC: 0.4390
#
# [152/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.001, batch_size=256
#   Val AUPRC: 0.4770, Test AUPRC: 0.4436
#
# [153/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.001, batch_size=512
#   Val AUPRC: 0.4713, Test AUPRC: 0.4513
#
# [154/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.002, batch_size=128
#   Val AUPRC: 0.4827, Test AUPRC: 0.4421
#
# [155/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.002, batch_size=256
#   Val AUPRC: 0.4770, Test AUPRC: 0.4164
#
# [156/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.2, lr=0.002, batch_size=512
#   Val AUPRC: 0.4826, Test AUPRC: 0.4505
#
# [157/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4828, Test AUPRC: 0.4700
#
# [158/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4810, Test AUPRC: 0.4697
#
# [159/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4827, Test AUPRC: 0.4713
#
# [160/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4765, Test AUPRC: 0.4457
#
# [161/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4889, Test AUPRC: 0.4460
#
# [162/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4809, Test AUPRC: 0.4657
#
# [163/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.001, batch_size=128
#   Val AUPRC: 0.4843, Test AUPRC: 0.4454
#
# [164/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.001, batch_size=256
#   Val AUPRC: 0.4771, Test AUPRC: 0.4456
#
# [165/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.001, batch_size=512
#   Val AUPRC: 0.4790, Test AUPRC: 0.4462
#
# [166/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.002, batch_size=128
#   Val AUPRC: 0.4837, Test AUPRC: 0.4556
#
# [167/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.002, batch_size=256
#   Val AUPRC: 0.4871, Test AUPRC: 0.4431
#
# [168/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.3, lr=0.002, batch_size=512
#   Val AUPRC: 0.4789, Test AUPRC: 0.4518
#
# [169/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4805, Test AUPRC: 0.4707
#
# [170/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4829, Test AUPRC: 0.4741
#
# [171/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4820, Test AUPRC: 0.4730
#
# [172/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4784, Test AUPRC: 0.4499
#
# [173/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4810, Test AUPRC: 0.4580
#
# [174/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4853, Test AUPRC: 0.4552
#
# [175/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.001, batch_size=128
#   Val AUPRC: 0.4777, Test AUPRC: 0.4316
#
# [176/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.001, batch_size=256
#   Val AUPRC: 0.4794, Test AUPRC: 0.4264
#
# [177/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.001, batch_size=512
#   Val AUPRC: 0.4809, Test AUPRC: 0.4627
#
# [178/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.002, batch_size=128
#   Val AUPRC: 0.4838, Test AUPRC: 0.4511
#
# [179/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.002, batch_size=256
#   Val AUPRC: 0.4820, Test AUPRC: 0.4440
#
# [180/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.4, lr=0.002, batch_size=512
#   Val AUPRC: 0.4840, Test AUPRC: 0.4380
#
# [181/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4830, Test AUPRC: 0.4643
#
# [182/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4842, Test AUPRC: 0.4768
#
# [183/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4833, Test AUPRC: 0.4743
#
# [184/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4843, Test AUPRC: 0.4477
#
# [185/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4833, Test AUPRC: 0.4572
#
# [186/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4863, Test AUPRC: 0.4658
#
# [187/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.001, batch_size=128
#   Val AUPRC: 0.4834, Test AUPRC: 0.4304
#
# [188/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.001, batch_size=256
#   Val AUPRC: 0.4858, Test AUPRC: 0.4441
#
# [189/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.001, batch_size=512
#   Val AUPRC: 0.4875, Test AUPRC: 0.4596
#
# [190/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.002, batch_size=128
#   Val AUPRC: 0.4745, Test AUPRC: 0.4380
#
# [191/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.002, batch_size=256
#   Val AUPRC: 0.4848, Test AUPRC: 0.4369
#
# [192/240] Testing config:
#   hidden_dims=(1024, 512), dropout=0.5, lr=0.002, batch_size=512
#   Val AUPRC: 0.4807, Test AUPRC: 0.4381
#
# [193/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4750, Test AUPRC: 0.4452
#
# [194/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4737, Test AUPRC: 0.4328
#
# [195/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4758, Test AUPRC: 0.4469
#
# [196/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4760, Test AUPRC: 0.4581
#
# [197/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4696, Test AUPRC: 0.4620
#
# [198/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4674, Test AUPRC: 0.4427
#
# [199/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.001, batch_size=128
#   Val AUPRC: 0.4768, Test AUPRC: 0.4476
#
# [200/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.001, batch_size=256
#   Val AUPRC: 0.4655, Test AUPRC: 0.4500
#
# [201/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.001, batch_size=512
#   Val AUPRC: 0.4684, Test AUPRC: 0.4503
#
# [202/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.002, batch_size=128
#   Val AUPRC: 0.4834, Test AUPRC: 0.4611
#
# [203/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.002, batch_size=256
#   Val AUPRC: 0.4887, Test AUPRC: 0.4531
#
# [204/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.2, lr=0.002, batch_size=512
#   Val AUPRC: 0.4715, Test AUPRC: 0.4444
#
# [205/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4766, Test AUPRC: 0.4433
#
# [206/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4801, Test AUPRC: 0.4424
#
# [207/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4803, Test AUPRC: 0.4507
#
# [208/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4724, Test AUPRC: 0.4295
#
# [209/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4670, Test AUPRC: 0.4566
#
# [210/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4689, Test AUPRC: 0.4430
#
# [211/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.001, batch_size=128
#   Val AUPRC: 0.4858, Test AUPRC: 0.4541
#
# [212/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.001, batch_size=256
#   Val AUPRC: 0.4786, Test AUPRC: 0.4556
#
# [213/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.001, batch_size=512
#   Val AUPRC: 0.4728, Test AUPRC: 0.4261
#
# [214/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.002, batch_size=128
#   Val AUPRC: 0.4760, Test AUPRC: 0.4553
#
# [215/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.002, batch_size=256
#   Val AUPRC: 0.4703, Test AUPRC: 0.4623
#
# [216/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.3, lr=0.002, batch_size=512
#   Val AUPRC: 0.4761, Test AUPRC: 0.4515
#
# [217/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4838, Test AUPRC: 0.4486
#
# [218/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4819, Test AUPRC: 0.4565
#
# [219/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4846, Test AUPRC: 0.4440
#
# [220/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4709, Test AUPRC: 0.4592
#
# [221/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4751, Test AUPRC: 0.4520
#
# [222/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4797, Test AUPRC: 0.4278
#
# [223/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.001, batch_size=128
#   Val AUPRC: 0.4699, Test AUPRC: 0.4329
#
# [224/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.001, batch_size=256
#   Val AUPRC: 0.4773, Test AUPRC: 0.4286
#
# [225/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.001, batch_size=512
#   Val AUPRC: 0.4778, Test AUPRC: 0.4202
#
# [226/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.002, batch_size=128
#   Val AUPRC: 0.4694, Test AUPRC: 0.4670
#
# [227/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.002, batch_size=256
#   Val AUPRC: 0.4786, Test AUPRC: 0.4616
#
# [228/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.4, lr=0.002, batch_size=512
#   Val AUPRC: 0.4758, Test AUPRC: 0.4319
#
# [229/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.0001, batch_size=128
#   Val AUPRC: 0.4847, Test AUPRC: 0.4556
#
# [230/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.0001, batch_size=256
#   Val AUPRC: 0.4858, Test AUPRC: 0.4609
#
# [231/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.0001, batch_size=512
#   Val AUPRC: 0.4898, Test AUPRC: 0.4679
#
# [232/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.0005, batch_size=128
#   Val AUPRC: 0.4762, Test AUPRC: 0.4355
#
# [233/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.0005, batch_size=256
#   Val AUPRC: 0.4815, Test AUPRC: 0.4382
#
# [234/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.0005, batch_size=512
#   Val AUPRC: 0.4781, Test AUPRC: 0.4453
#
# [235/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.001, batch_size=128
#   Val AUPRC: 0.4736, Test AUPRC: 0.4551
#
# [236/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.001, batch_size=256
#   Val AUPRC: 0.4862, Test AUPRC: 0.4209
#
# [237/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.001, batch_size=512
#   Val AUPRC: 0.4755, Test AUPRC: 0.4263
#
# [238/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.002, batch_size=128
#   Val AUPRC: 0.4871, Test AUPRC: 0.4367
#
# [239/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.002, batch_size=256
#   Val AUPRC: 0.4767, Test AUPRC: 0.4286
#
# [240/240] Testing config:
#   hidden_dims=(1024, 512, 256), dropout=0.5, lr=0.002, batch_size=512
#   Val AUPRC: 0.4838, Test AUPRC: 0.4517
#
# Completed 240 configurations.

# %% [markdown]
# ## Analyze results and find best configuration
#
# Convert results to DataFrame, identify the best configuration by validation AUPRC, and save results.

# %%
results_df = pd.DataFrame(results)

# Filter out errors
valid_results = results_df[~results_df["best_val_auprc"].isna()].copy()

if len(valid_results) > 0:
    # Sort by validation AUPRC
    valid_results = valid_results.sort_values("best_val_auprc", ascending=False)
    
    print("Top 10 configurations by validation AUPRC:")
    print(valid_results[["hidden_dims", "dropout", "learning_rate", "batch_size",
                         "best_val_auprc", "test_auprc", "test_f1", "test_mcc"]].head(10).to_string())
    
    # Best configuration
    best_config = valid_results.iloc[0]
    print("\n" + "="*60)
    print("BEST CONFIGURATION:")
    print("="*60)
    print(f"Hidden dims: {best_config['hidden_dims']}")
    print(f"Dropout: {best_config['dropout']}")
    print(f"Learning rate: {best_config['learning_rate']}")
    print(f"Batch size: {best_config['batch_size']}")
    print(f"\nValidation AUPRC: {best_config['best_val_auprc']:.4f}")
    print(f"Test AUPRC: {best_config['test_auprc']:.4f}")
    print(f"Test Precision: {best_config['test_precision']:.4f}")
    print(f"Test Recall: {best_config['test_recall']:.4f}")
    print(f"Test F1: {best_config['test_f1']:.4f}")
    print(f"Test MCC: {best_config['test_mcc']:.4f}")
    print("="*60)
else:
    print("No valid results found.")
# Out:
# Top 10 configurations by validation AUPRC:
#           hidden_dims  dropout  learning_rate  batch_size  best_val_auprc  test_auprc   test_f1
# 150       (1024, 512)      0.2         0.0010         128        0.490220    0.438999  0.460177
# 230  (1024, 512, 256)      0.5         0.0001         512        0.489804    0.467948  0.419941
# 160       (1024, 512)      0.3         0.0005         256        0.488941    0.445971  0.407932
# 202  (1024, 512, 256)      0.2         0.0020         256        0.488684    0.453071  0.464017
# 188       (1024, 512)      0.5         0.0010         512        0.487497    0.459593  0.424309
# 166       (1024, 512)      0.3         0.0020         256        0.487120    0.443074  0.454575
# 237  (1024, 512, 256)      0.5         0.0020         128        0.487069    0.436690  0.449508
# 185       (1024, 512)      0.5         0.0005         512        0.486284    0.465828  0.449210
# 235  (1024, 512, 256)      0.5         0.0010         256        0.486177    0.420923  0.409844
# 210  (1024, 512, 256)      0.3         0.0010         128        0.485839    0.454141  0.461488
#
# ============================================================
# BEST CONFIGURATION:
# ============================================================
# Hidden dims: (1024, 512)
# Dropout: 0.2
# Learning rate: 0.001
# Batch size: 128
#
# Validation AUPRC: 0.4902
# Test AUPRC: 0.4390
# Test Precision: 0.3605
# Test Recall: 0.6360
# Test F1: 0.4602
# ============================================================

# %% [markdown]
# ## Save results
#
# Save all results to CSV and the best configuration to JSON for easy reuse.

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Save all results
results_csv = RESULTS_DIR / f"hyperparameter_search_results_{timestamp}.csv"
results_df.to_csv(results_csv, index=False)
print(f"Saved all results to: {results_csv}")

# Save best configuration
if len(valid_results) > 0:
    best_config_dict = {
        "timestamp": timestamp,
        "hidden_dims": eval(best_config["hidden_dims"]),  # Convert string back to tuple
        "dropout": float(best_config["dropout"]),
        "learning_rate": float(best_config["learning_rate"]),
        "batch_size": int(best_config["batch_size"]),
        "metrics": {
            "best_val_auprc": float(best_config["best_val_auprc"]),
            "test_precision": float(best_config["test_precision"]),
            "test_recall": float(best_config["test_recall"]),
            "test_f1": float(best_config["test_f1"]),
            "test_auprc": float(best_config["test_auprc"]),
            "test_mcc": float(best_config["test_mcc"]),
        }
    }
    
    best_config_json = RESULTS_DIR / f"best_mlp_config_{timestamp}.json"
    with open(best_config_json, "w") as f:
        json.dump(best_config_dict, f, indent=2)
    print(f"Saved best configuration to: {best_config_json}")
    
    # Also save a human-readable summary
    summary_txt = RESULTS_DIR / f"hyperparameter_search_summary_{timestamp}.txt"
    with open(summary_txt, "w") as f:
        f.write("Hyperparameter Search Summary\n")
        f.write("="*60 + "\n\n")
        f.write(f"Timestamp: {timestamp}\n")
        f.write(f"Total configurations tested: {len(configs)}\n")
        f.write(f"Valid results: {len(valid_results)}\n\n")
        f.write("Best Configuration:\n")
        f.write(f"  Hidden dims: {best_config_dict['hidden_dims']}\n")
        f.write(f"  Dropout: {best_config_dict['dropout']}\n")
        f.write(f"  Learning rate: {best_config_dict['learning_rate']}\n")
        f.write(f"  Batch size: {best_config_dict['batch_size']}\n\n")
        f.write("Best Metrics:\n")
        for k, v in best_config_dict["metrics"].items():
            f.write(f"  {k}: {v:.4f}\n")
    print(f"Saved summary to: {summary_txt}")
    
    # Save a summary figure (top configs by val AUPRC)
    import matplotlib.pyplot as plt
    top = valid_results.head(10)
    fig, ax = plt.subplots(figsize=(10, 4))
    x = range(len(top))
    ax.bar([i - 0.2 for i in x], top["best_val_auprc"], width=0.2, label="Val AUPRC")
    ax.bar([i for i in x], top["test_auprc"], width=0.2, label="Test AUPRC")
    ax.bar([i + 0.2 for i in x], top["test_mcc"], width=0.2, label="Test MCC")
    ax.set_xticks(x)
    ax.set_xticklabels([f"{r['hidden_dims']}" for _, r in top.iterrows()], rotation=45, ha="right")
    ax.set_ylabel("Score")
    ax.legend()
    ax.set_title(f"Top 10 configs by val AUPRC (PTM: {PTM_TYPE})")
    plt.tight_layout()
    fig_path = RESULTS_DIR / f"top10_configs_{timestamp}.png"
    plt.savefig(fig_path)
    plt.close()
    print(f"Saved summary figure to: {fig_path}")
# Out:
# Saved all results to: ../docs/hyperparameter_search_results_20260207_235652.csv
# Saved best configuration to: ../docs/best_mlp_config_20260207_235652.json
# Saved summary to: ../docs/hyperparameter_search_summary_20260207_235652.txt
